# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Onions.csv')
# Out:
# /var/folders/3k/3lbygck964ldccpncrf48vsw0000gn/T/ipykernel_82680/1708782374.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Onions.csv')

# %%
df.head()
# Out:
#   Commodity Name City Name Type        Package Variety            Sub Variety  \
# 0     ONIONS DRY   ATLANTA  NaN  40 lb cartons  YELLOW  GRANEX - MARKED SWEET
# 1     ONIONS DRY   ATLANTA  NaN  40 lb cartons  YELLOW  GRANEX - MARKED SWEET
# 2     ONIONS DRY   ATLANTA  NaN    50 lb sacks  YELLOW                  GRANO
# 3     ONIONS DRY   ATLANTA  NaN    50 lb sacks  YELLOW                  GRANO
# 4     ONIONS DRY   ATLANTA  NaN    50 lb sacks  YELLOW                  GRANO
#
#   Grade        Date  Low Price  High Price  ...  Condition  Appearance  \
# 0   NaN  08/21/2023      30.00       32.00  ...        NaN         NaN
# 1   NaN  08/21/2023      32.25       32.25  ...        NaN         NaN
# 2   NaN  08/21/2023      28.00       30.50  ...        NaN         NaN
# 3   NaN  08/21/2023      26.00       28.00  ...        NaN         NaN
# 4   NaN  08/21/2023      21.00       24.00  ...        NaN         NaN
#
# ...

# %% [raw]
#     # Replace colname
#     # Drop the Unwanted columns
#     # select the variety type as Red
# # Select the package that has the word "sacks" in the sentence
#     # Combine the 2 columns of prices by taking the average and create a new column and delete the rest
#     # Fill in the blank values in type with 'UnOrganic'
# # Save the new csv

# %%
df.drop(columns=['Sub Variety', 'Grade', 'Mostly Low','Mostly High','Origin','Origin District','Item Size','Color', 'Environment', 'Unit of Sale', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Repack', 'Trans Mode', 'Offerings', 'Market Tone', 'Price Comment', 'Comments'], inplace=True)

# %%
df
# Out:
#       Commodity Name      City Name Type                Package     Variety  \
# 0         ONIONS DRY        ATLANTA  NaN          40 lb cartons      YELLOW
# 1         ONIONS DRY        ATLANTA  NaN          40 lb cartons      YELLOW
# 2         ONIONS DRY        ATLANTA  NaN            50 lb sacks      YELLOW
# 3         ONIONS DRY        ATLANTA  NaN            50 lb sacks      YELLOW
# 4         ONIONS DRY        ATLANTA  NaN            50 lb sacks      YELLOW
# ...              ...            ...  ...                    ...         ...
# 73182     ONIONS DRY  SAN FRANCISCO  NaN            50 lb sacks         RED
# 73183     ONIONS DRY  SAN FRANCISCO  NaN            50 lb sacks         RED
# 73184     ONIONS DRY  SAN FRANCISCO  NaN  cartons 12 10-oz bags  PEARL TYPE
# 73185     ONIONS DRY  SAN FRANCISCO  NaN  cartons 12 10-oz bags  PEARL TYPE
# 73186     ONIONS DRY  SAN FRANCISCO  NaN  cartons 12 10-oz bags  PEARL TYPE
#
#              Date  Low Price  High Price
# ...

# %%
# Define the values to be removed
values_to_remove = ['WHITE', 'YELLOW','PEARL TYPE','SETS']

# Remove rows where 'car_type' is in the list of values to remove
df1 = df[~df['Variety'].isin(values_to_remove)]

# %%
df1
# Out:
#       Commodity Name      City Name Type      Package Variety        Date  \
# 13        ONIONS DRY        ATLANTA  NaN  25 lb sacks     RED  08/21/2023
# 36        ONIONS DRY      BALTIMORE  NaN  10 lb sacks     RED  08/21/2023
# 37        ONIONS DRY      BALTIMORE  NaN  10 lb sacks     RED  08/21/2023
# 38        ONIONS DRY      BALTIMORE  NaN  10 lb sacks     RED  08/21/2023
# 39        ONIONS DRY      BALTIMORE  NaN  25 lb sacks     RED  08/21/2023
# ...              ...            ...  ...          ...     ...         ...
# 73179     ONIONS DRY  SAN FRANCISCO  NaN  50 lb sacks     RED  05/26/2023
# 73180     ONIONS DRY  SAN FRANCISCO  NaN  50 lb sacks     RED  05/26/2023
# 73181     ONIONS DRY  SAN FRANCISCO  NaN  50 lb sacks     RED  05/26/2023
# 73182     ONIONS DRY  SAN FRANCISCO  NaN  50 lb sacks     RED  05/26/2023
# 73183     ONIONS DRY  SAN FRANCISCO  NaN  50 lb sacks     RED  05/26/2023
#
#        Low Price  High Price
# 13          16.0        19.0
# ...

# %%
value_counts = df1['Variety'].value_counts()

# %%
value_counts
# Out:
# RED    19231
# Name: Variety, dtype: int64

# %%
df1['Type'] = df1['Type'].fillna('InOrganic')
# Out:
# /var/folders/3k/3lbygck964ldccpncrf48vsw0000gn/T/ipykernel_82680/87202931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Type'] = df1['Type'].fillna('InOrganic')

# %%
value_counts_Type = df1['Type'].value_counts()

# %%
value_counts_Type
# Out:
# InOrganic    17521
# Organic       2002
# Name: Type, dtype: int64

# %%
# df = df[df['Package'].str.contains('sacks')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df = df[df['Package'].str.contains('sacks')]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
df2 = df1['total_price'] = df1[['Low Price', 'High Price']].mean(axis=1)
# Out:
# /var/folders/3k/3lbygck964ldccpncrf48vsw0000gn/T/ipykernel_82680/2100136380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2 = df1['total_price'] = df1[['Low Price', 'High Price']].mean(axis=1)

# %%
np.dtype(df2)
# Out:
# dtype('float64')

# %%
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  Low Price  High Price  total_price
# 13     08/21/2023       16.0        19.0        17.50
# ...

# %%
df1['total_price'] = df1.apply(lambda row: row[['Low Price', 'High Price']].mean(), axis=1)
# Out:
# /var/folders/3k/3lbygck964ldccpncrf48vsw0000gn/T/ipykernel_82680/1104609983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['total_price'] = df1.apply(lambda row: row[['Low Price', 'High Price']].mean(), axis=1)

# %%
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  Low Price  High Price  total_price
# 13     08/21/2023       16.0        19.0        17.50
# ...

# %%
columns_to_drop = ['Low Price', 'High Price']
df1 = df1.drop(columns=columns_to_drop)

# %%
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  total_price
# 13     08/21/2023        17.50
# 36     08/21/2023         8.25
# 37     08/21/2023         8.00
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19523 entries, 13 to 73183
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  19523 non-null  object
#  1   City Name       19523 non-null  object
#  2   Type            19523 non-null  object
#  3   Package         19498 non-null  object
#  4   Variety         19231 non-null  object
#  5   Date            19523 non-null  object
#  6   total_price     19058 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 1.2+ MB

# %%
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  total_price
# 13     08/21/2023        17.50
# 36     08/21/2023         8.25
# 37     08/21/2023         8.00
# ...

# %%
distinct_values = df1['Package'].unique()
distinct_values
# Out:
# array(['25 lb sacks', '10 lb sacks',
#        'master container 20 2-lb mesh sacks',
#        'master container 24 2-lb mesh sacks', '50 lb sacks',
#        'master container 5 10-lb mesh sacks', '40 lb cartons',
#        'cartons 12 2-lb mesh sacks', 'master container 16 3-lb film bags',
#        '30 kg sacks', 'containers', 'master container 16 3-lb mesh sacks',
#        '25 lb cartons', 'master container 5 10-lb film bags',
#        'master container 20 2-lb film bags', nan,
#        'master container 10 5-lb mesh sacks',
#        'master container 18 2-lb mesh sacks'], dtype=object)

# %%
# NORMALIZE THE PACKAGE COLUMN BY CONVERTING ALL OF THE ROWS TO LB SCALE , CREATE A NEW COLUMN TO STORE THE  VALUES IN LB SCALE 

# Define a mapping dictionary for normalization
package_mapping = {
    '25 lb sacks': 25,
    '10 lb sacks': 10,  
    'master container 20 2-lb mesh sacks': 40,
    'master container 24 2-lb mesh sacks': 48,
    '50 lb sacks': 50,  
    'master container 5 10-lb mesh sack': 50,  
    '40 lb cartons': 530, # 1 carton is 13 pounds 
    'cartons 12 2-lb mesh sacks': 156, # 12*13 
    'master container 16 3-lb film bags': 2304, # 1 film bag is 48lbs
    '25 lb cartons' : 325,
    'master container 5 10-lb film bags': 2400,
    'nan': 0,
    'master container 10 5-lb mesh sacks': 50,
    'master container 18 2-lb mesh sacks' : 36,
}

# Map the values in the 'Package' column to numeric values
df1['Package Size in pound'] = df['Package'].map(package_mapping)

# Display the preprocessed data
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  total_price  Package Size in pound
# 13     08/21/2023        17.50                   25.0
# ...

# %%
df1['Price per Pound'] = df1['total_price'] / df1['Package Size in pound']

# %%
df1
# Out:
#       Commodity Name      City Name       Type      Package Variety  \
# 13        ONIONS DRY        ATLANTA  InOrganic  25 lb sacks     RED
# 36        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 37        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 38        ONIONS DRY      BALTIMORE  InOrganic  10 lb sacks     RED
# 39        ONIONS DRY      BALTIMORE  InOrganic  25 lb sacks     RED
# ...              ...            ...        ...          ...     ...
# 73179     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73180     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73181     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73182     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
# 73183     ONIONS DRY  SAN FRANCISCO  InOrganic  50 lb sacks     RED
#
#              Date  total_price  Package Size in pound  Price per Pound
# 13     08/21/2023        17.50                   25.0            0.700
# ...

# %%
df3 = pd.read_csv('Jalapeno.csv')

# %%
df3.head()
# Out:
#    Commodity Name  City Name Type                      Package   Variety  \
# 0  PEPPERS, OTHER    ATLANTA  NaN  1 1/9 bushel cartons/crates  JALAPENO
# 1  PEPPERS, OTHER    ATLANTA  NaN  1 1/9 bushel cartons/crates  JALAPENO
# 2  PEPPERS, OTHER    ATLANTA  NaN  1 1/9 bushel cartons/crates  JALAPENO
# 3  PEPPERS, OTHER    ATLANTA  NaN            1/2 bushel crates  JALAPENO
# 4  PEPPERS, OTHER  BALTIMORE  NaN         1 1/9 bushel cartons  JALAPENO
#
#   Sub Variety  Grade        Date  Low Price  High Price  ...  Condition  \
# 0         NaN    NaN  07/28/2023       31.0        35.0  ...        NaN
# 1         NaN    NaN  07/28/2023       40.0        44.0  ...        NaN
# 2         NaN    NaN  07/28/2023       30.0        31.0  ...        NaN
# 3         NaN    NaN  07/28/2023       30.0        31.0  ...        NaN
# 4         NaN    NaN  07/28/2023       35.0        35.0  ...        NaN
#
#    Appearance Storage Crop Repack Trans Mode Offerings    Market Tone  \
# ...

# %%
df3.drop(columns=['Sub Variety', 'Grade', 'Mostly Low','Mostly High','Origin','Origin District','Item Size','Color', 'Environment', 'Unit of Sale', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Repack', 'Trans Mode', 'Offerings', 'Market Tone', 'Price Comment', 'Comments'], inplace=True)

# %%
df3
# Out:
#       Commodity Name      City Name     Type                      Package  \
# 0     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 1     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 2     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 3     PEPPERS, OTHER        ATLANTA      NaN            1/2 bushel crates
# 4     PEPPERS, OTHER      BALTIMORE      NaN         1 1/9 bushel cartons
# ...              ...            ...      ...                          ...
# 9129  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9130  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9131  PEPPERS, OTHER  SAN FRANCISCO  Organic                10 lb cartons
# 9132  PEPPERS, OTHER  SAN FRANCISCO      NaN                30 lb cartons
# 9133  PEPPERS, OTHER   TORONTO, ONT      NaN                10 lb cartons
#
#        Variety        Date  Low Price  High Price
# ...

# %%
value_counts_J = df3['Type'].value_counts()

# %%
value_counts_J
# Out:
# Organic    351
# Name: Type, dtype: int64

# %%
df3['Total_price'] = df3.apply(lambda row: row[['Low Price', 'High Price']].mean(), axis=1)

# %%
df3
# Out:
#       Commodity Name      City Name     Type                      Package  \
# 0     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 1     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 2     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 3     PEPPERS, OTHER        ATLANTA      NaN            1/2 bushel crates
# 4     PEPPERS, OTHER      BALTIMORE      NaN         1 1/9 bushel cartons
# ...              ...            ...      ...                          ...
# 9129  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9130  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9131  PEPPERS, OTHER  SAN FRANCISCO  Organic                10 lb cartons
# 9132  PEPPERS, OTHER  SAN FRANCISCO      NaN                30 lb cartons
# 9133  PEPPERS, OTHER   TORONTO, ONT      NaN                10 lb cartons
#
#        Variety        Date  Low Price  High Price  Total_price
# ...

# %%
columns_to_drop = ['Low Price', 'High Price']
df3 = df3.drop(columns=columns_to_drop)

# %%
df3
# Out:
#       Commodity Name      City Name     Type                      Package  \
# 0     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 1     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 2     PEPPERS, OTHER        ATLANTA      NaN  1 1/9 bushel cartons/crates
# 3     PEPPERS, OTHER        ATLANTA      NaN            1/2 bushel crates
# 4     PEPPERS, OTHER      BALTIMORE      NaN         1 1/9 bushel cartons
# ...              ...            ...      ...                          ...
# 9129  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9130  PEPPERS, OTHER   PHILADELPHIA      NaN             40 lb containers
# 9131  PEPPERS, OTHER  SAN FRANCISCO  Organic                10 lb cartons
# 9132  PEPPERS, OTHER  SAN FRANCISCO      NaN                30 lb cartons
# 9133  PEPPERS, OTHER   TORONTO, ONT      NaN                10 lb cartons
#
#        Variety        Date  Total_price
# ...

# %%
df3['Type'] = df3['Type'].fillna('InOrganic')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  9134 non-null   object
#  1   City Name       9134 non-null   object
#  2   Type            9134 non-null   object
#  3   Package         9134 non-null   object
#  4   Variety         9134 non-null   object
#  5   Date            9134 non-null   object
#  6   Total_price     8870 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 499.6+ KB

# %%
distinct_values = df3['Package'].unique()
distinct_values
# Out:
# array(['1 1/9 bushel cartons/crates', '1/2 bushel crates',
#        '1 1/9 bushel cartons', '1/2 bushel cartons', '40 lb containers',
#        'crates', '25 lb containers', '10 lb cartons', '2 kg cartons',
#        '30 lb cartons', 'bushel cartons', '30 kg sacks', 'cartons/crates',
#        '1 1/9 bushel crates', '15 lb cartons', '3 kg cartons'],
#       dtype=object)

# %%
# NORMALIZE THE PACKAGE COLUMN BY CONVERTING ALL OF THE ROWS TO LB SCALE , CREATE A NEW COLUMN TO STORE THE  VALUES IN LB SCALE 

# Define a mapping dictionary for normalization
package_mapping = {
    '1 1/9 bushel cartons/crates': 33.3,  #Bushel basket, sacks, carton or crate - 30 pounds
    '1/2 bushel crates': 15,  
    '1 1/9 bushel cartons': 33.3,
    '1/2 bushel cartons': 15,
    '40 lb containers': 1000,  # container is 25 pounds
    'crates': 30,  
    '25 lb containers': 625, 
    '10 lb cartons': 300, 
    '2 kg cartons': 680, # 1 kg - 2.2 lbs
    '30 lb cartons' : 750,
    'bushel cartons': 750,
    '30 kg sacks': 1980,
    'cartons/crates': 30,
    '1 1/9 bushel crates' : 33.33,
    '15 lb cartons' : 450,
    '3 kg cartons':198 ,
}

# Map the values in the 'Package' column to numeric values
df3['Package Size in pound'] = df3['Package'].map(package_mapping)

# Display the preprocessed data
df3
# Out:
#       Commodity Name      City Name       Type                      Package  \
# 0     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 1     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 2     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 3     PEPPERS, OTHER        ATLANTA  InOrganic            1/2 bushel crates
# 4     PEPPERS, OTHER      BALTIMORE  InOrganic         1 1/9 bushel cartons
# ...              ...            ...        ...                          ...
# 9129  PEPPERS, OTHER   PHILADELPHIA  InOrganic             40 lb containers
# 9130  PEPPERS, OTHER   PHILADELPHIA  InOrganic             40 lb containers
# 9131  PEPPERS, OTHER  SAN FRANCISCO    Organic                10 lb cartons
# 9132  PEPPERS, OTHER  SAN FRANCISCO  InOrganic                30 lb cartons
# 9133  PEPPERS, OTHER   TORONTO, ONT  InOrganic                10 lb cartons
#
# ...

# %%
df3['Price per Pound'] = df3['Total_price'] / df3['Package Size in pound']

# %%
df3
# Out:
#       Commodity Name      City Name       Type                      Package  \
# 0     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 1     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 2     PEPPERS, OTHER        ATLANTA  InOrganic  1 1/9 bushel cartons/crates
# 3     PEPPERS, OTHER        ATLANTA  InOrganic            1/2 bushel crates
# 4     PEPPERS, OTHER      BALTIMORE  InOrganic         1 1/9 bushel cartons
# ...              ...            ...        ...                          ...
# 9129  PEPPERS, OTHER   PHILADELPHIA  InOrganic             40 lb containers
# 9130  PEPPERS, OTHER   PHILADELPHIA  InOrganic             40 lb containers
# 9131  PEPPERS, OTHER  SAN FRANCISCO    Organic                10 lb cartons
# 9132  PEPPERS, OTHER  SAN FRANCISCO  InOrganic                30 lb cartons
# 9133  PEPPERS, OTHER   TORONTO, ONT  InOrganic                10 lb cartons
#
# ...
